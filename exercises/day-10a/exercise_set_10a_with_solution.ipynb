# %% [markdown]
# # Pandas fundamentals

# %% [markdown]
# <div align="right"><button><a href="https://colab.research.google.com/github/QuantEcon/africa-summer-course-2024/blob/main/exercises/day-09/exercise_set_9_with_solution.ipynb"><img src="" heght="10px"/><img
#   src="https://colab.research.google.com/assets/colab-badge.svg"
#   alt="open with Colab" width="100px"/></a></button></div>

# %% [markdown]
# #### Written for the QuantEcon Africa Workshop (July 2024)
# #### Author: [Shu Hu](https://shu-hu.com/intro.html) and [Hengcheng Zhang](https://github.com/HengchengZhang)

# %% [markdown]
# First we install and import necessary packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1 (View data)

# %% [markdown]
# Given the dataframe below you are required to do the following exercises.

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/QuantEcon/lecture-python-programming/master/source/_static/lecture_specific/pandas/data/test_pwt.csv')

# %%
df
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %% [markdown]
# ### Exercise 1.1
#
# Show the top 5 rows of the dataframe ``df``.

# %%
df.head(5)
# Out:
#      country country isocode  year          POP       XRAT         tcgdp  \
# 0  Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1  Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2      India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3     Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4     Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954

# %% [markdown]
# ### Exercise 1.2
#
# Show the bottom 5 rows of the dataframe ``df``.

# %%
df.tail(5)
# Out:
#          country country isocode  year         POP       XRAT         tcgdp  \
# 3         Israel             ISR  2000    6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000   11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000   45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000  282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000    3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %% [markdown]
# ### Exercise 1.3
#
# Show a quick statistic summary of the dataframe ``df``.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          8 non-null      object
#  1   country isocode  8 non-null      object
#  2   year             8 non-null      int64
#  3   POP              8 non-null      float64
#  4   XRAT             8 non-null      float64
#  5   tcgdp            8 non-null      float64
#  6   cc               8 non-null      float64
#  7   cg               8 non-null      float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 644.0+ bytes

# %%
# Alternative solution
df.describe()
# Out:
#          year           POP       XRAT         tcgdp         cc         cg
# count     8.0  8.000000e+00   8.000000  8.000000e+00   8.000000   8.000000
# mean   2000.0  1.763826e+05  16.415811  1.606312e+06  71.404995   8.145477
# std       0.0  3.479223e+05  22.758175  3.397025e+06   5.318015   3.383397
# min    2000.0  3.219793e+03   0.999500  5.026222e+03  64.436451   5.108068
# 25%    2000.0  1.037977e+04   1.543623  1.032544e+05  66.963157   5.689611
# 50%    2000.0  2.819442e+04   5.508580  2.611573e+05  72.532882   6.376276
# 75%    2000.0  1.043411e+05  20.310094  8.383896e+05  74.959919  10.614755
# max    2000.0  1.006300e+06  59.543808  9.898700e+06  78.978740  14.072206

# %% [markdown]
# ### Exercise 1.4
#
# Transpose the dataframe ``df``.

# %%
df.T
# Out:
#                             0            1             2             3  \
# country             Argentina    Australia         India        Israel
# country isocode           ARG          AUS           IND           ISR
# year                     2000         2000          2000          2000
# POP                 37335.653    19053.186   1006300.297       6114.57
# XRAT                   0.9995      1.72483       44.9416       4.07733
# tcgdp            295072.21869  541804.6521  1728144.3748  129253.89423
# cc                  75.716805    67.759026     64.575551     64.436451
# cg                   5.578804     6.720098     14.072206     10.266688
#
#                            4             5              6             7
# country               Malawi  South Africa  United States       Uruguay
# country isocode          MWI           ZAF            USA           URY
# year                    2000          2000           2000          2000
# POP                11801.505     45064.098     282171.957      3219.793
# XRAT               59.543808       6.93983            1.0     12.099592
# tcgdp            5026.221784  227242.36949      9898700.0  25255.961693
# cc                 74.707624      72.71871      72.347054      78.97874
# cg                 11.658954      5.726546       6.032454      5.108068

# %% [markdown]
# ### Exercise 1.5
#
# Sort the dataframe ``df`` by values in column ``tcgdp`` ascendingly.

# %%
df.sort_values(by="tcgdp")
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
#
#           cc         cg
# 4  74.707624  11.658954
# 7  78.978740   5.108068
# 3  64.436451  10.266688
# 5  72.718710   5.726546
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 6  72.347054   6.032454

# %% [markdown]
# ### Exercise 2 (Select data)

# %% [markdown]
# ### Exercise 2.1
#
# Select the column ``tcgdp`` from the dataframe ``df``, yielding a series.

# %%
df["tcgdp"]
# Out:
# 0    2.950722e+05
# 1    5.418047e+05
# 2    1.728144e+06
# 3    1.292539e+05
# 4    5.026222e+03
# 5    2.272424e+05
# 6    9.898700e+06
# 7    2.525596e+04
# Name: tcgdp, dtype: float64

# %%
# Alternative solution
df.tcgdp
# Out:
# 0    2.950722e+05
# 1    5.418047e+05
# 2    1.728144e+06
# 3    1.292539e+05
# 4    5.026222e+03
# 5    2.272424e+05
# 6    9.898700e+06
# 7    2.525596e+04
# Name: tcgdp, dtype: float64

# %% [markdown]
# ### Exercise 2.2
#
# Select the top 3 rows from the dataframe ``df``.

# %%
df[:3]
# Out:
#      country country isocode  year          POP      XRAT         tcgdp  \
# 0  Argentina             ARG  2000    37335.653   0.99950  2.950722e+05
# 1  Australia             AUS  2000    19053.186   1.72483  5.418047e+05
# 2      India             IND  2000  1006300.297  44.94160  1.728144e+06
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206

# %% [markdown]
# ### Exercise 2.3
#
#
# Get the first row of data across all the columns.

# %%
# Use df.iloc for integer index
df.iloc[0]
# Out:
# country               Argentina
# country isocode             ARG
# year                       2000
# POP                   37335.653
# XRAT                     0.9995
# tcgdp              295072.21869
# cc                    75.716805
# cg                     5.578804
# Name: 0, dtype: object

# %% [markdown]
# ### Exercise 2.4
#
# Select all values on two columns ``country`` and ``POP``.

# %%
df[["country", "POP"]]
# Out:
#          country          POP
# 0      Argentina    37335.653
# 1      Australia    19053.186
# 2          India  1006300.297
# 3         Israel     6114.570
# 4         Malawi    11801.505
# 5   South Africa    45064.098
# 6  United States   282171.957
# 7        Uruguay     3219.793

# %% [markdown]
# You can also use the ``loc`` method which gives you access to locators for both column and row selection.

# %%
df.loc[:, ["country", "POP"]]
# Out:
#          country          POP
# 0      Argentina    37335.653
# 1      Australia    19053.186
# 2          India  1006300.297
# 3         Israel     6114.570
# 4         Malawi    11801.505
# 5   South Africa    45064.098
# 6  United States   282171.957
# 7        Uruguay     3219.793

# %% [markdown]
# ### Exercise 2.5
#
# Select values in rows 2-4 on two columns ``country`` and ``POP``.

# %%
df.loc[2:4, ["country", "POP"]]
# Out:
#   country          POP
# 2   India  1006300.297
# 3  Israel     6114.570
# 4  Malawi    11801.505

# %% [markdown]
# ### Exercise 2.6
#
# Get a scalar value for the 2nd row in the column ``POP`` which should be ``1006300.297``.

# %%
df.loc[2, "POP"]
# Out:
# 1006300.297

# %%
# The .at property acts only on single value pairs for columns and rows, 
# while .loc can include ranges and more advanced filters
df.at[2, "POP"]
# Out:
# 1006300.297

# %% [markdown]
# ### Exercise 3 (Boolean indexing)

# %% [markdown]
# ### Exercise 3.1
#
# Select data with column ``POP``'s values greater than ``30_000``.

# %%
df[df['POP'] > 30_000]
# Out:
#          country country isocode  year          POP      XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.99950  2.950722e+05
# 2          India             IND  2000  1006300.297  44.94160  1.728144e+06
# 5   South Africa             ZAF  2000    45064.098   6.93983  2.272424e+05
# 6  United States             USA  2000   282171.957   1.00000  9.898700e+06
#
#           cc         cg
# 0  75.716805   5.578804
# 2  64.575551  14.072206
# 5  72.718710   5.726546
# 6  72.347054   6.032454

# %% [markdown]
# ### Exercise 3.2
#
# We see

# %%
df1 = df.copy()
df1
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
df1["X"] = ["A", "B", "C", "D", "E", "F", "G","H"]

# %%
df1
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg  X
# 0  75.716805   5.578804  A
# 1  67.759026   6.720098  B
# 2  64.575551  14.072206  C
# 3  64.436451  10.266688  D
# 4  74.707624  11.658954  E
# 5  72.718710   5.726546  F
# 6  72.347054   6.032454  G
# 7  78.978740   5.108068  H

# %% [markdown]
# Filter rows containing ``A``, ``C``, ``G`` in column ``X`` using method [isin()](https://pandas.pydata.org/docs/reference/api/pandas.Series.isin.html#pandas.Series.isin).

# %%
df1[df1["X"].isin(["A", "C", "G"])]
# Out:
#          country country isocode  year          POP     XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.9995  2.950722e+05
# 2          India             IND  2000  1006300.297  44.9416  1.728144e+06
# 6  United States             USA  2000   282171.957   1.0000  9.898700e+06
#
#           cc         cg  X
# 0  75.716805   5.578804  A
# 2  64.575551  14.072206  C
# 6  72.347054   6.032454  G

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# Let's consider the following dataframe ``df``.

# %%
url = "https://datascience.quantecon.org/assets/data/bball.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#    Year  Player Team  TeamName  Games   Pts  Assist  Rebound
# 0  2015   Curry  GSW  Warriors     79  30.1     6.7      5.4
# 1  2016   Curry  GSW  Warriors     79  25.3     6.6      4.5
# 2  2017   Curry  GSW  Warriors     51  26.4     6.1      5.1
# 3  2015  Durant  OKC   Thunder     72  28.2     5.0      8.2
# 4  2016  Durant  GSW  Warriors     62  25.1     4.8      8.3
# 5  2017  Durant  GSW  Warriors     68  26.4     5.4      6.8
# 6  2015   Ibaka  OKC   Thunder     78  12.6     0.8      6.8
# 7  2016   Ibaka  ORL     Magic     56  15.1     1.1      6.8
# 8  2016   Ibaka  TOR   Raptors     23  14.2     0.7      6.8

# %% [markdown]
# ### Exercise 4.1 (Merge vs Group)
#
# Given two dataframes ``df1`` and ``df2``, concatenate them together.

# %%
df1 = df[0:3]
df2 = df[3:]

# %%
dfs = [df1, df2]
pd.concat(dfs)
# Out:
#    Year  Player Team  TeamName  Games   Pts  Assist  Rebound
# 0  2015   Curry  GSW  Warriors     79  30.1     6.7      5.4
# 1  2016   Curry  GSW  Warriors     79  25.3     6.6      4.5
# 2  2017   Curry  GSW  Warriors     51  26.4     6.1      5.1
# 3  2015  Durant  OKC   Thunder     72  28.2     5.0      8.2
# 4  2016  Durant  GSW  Warriors     62  25.1     4.8      8.3
# 5  2017  Durant  GSW  Warriors     68  26.4     5.4      6.8
# 6  2015   Ibaka  OKC   Thunder     78  12.6     0.8      6.8
# 7  2016   Ibaka  ORL     Magic     56  15.1     1.1      6.8
# 8  2016   Ibaka  TOR   Raptors     23  14.2     0.7      6.8

# %% [markdown]
# ### Exercise 4.2 (Group)
#
# Group the dataframe ``df`` by column ``Player`` and apply the ``sum()`` method to the resulting groups.

# %%
df.groupby("Player").sum(numeric_only=True)
# Out:
#         Year  Games   Pts  Assist  Rebound
# Player
# Curry   6048    209  81.8    19.4     15.0
# Durant  6048    202  79.7    15.2     23.3
# Ibaka   6047    157  41.9     2.6     20.4

# %% [markdown]
# ### Exercise 4.3 (Group)
#
# Group the dataframe ``df`` by column ``Player`` and apply ``mean()`` method to the resulting groups.

# %%
df.groupby("Player").mean(numeric_only=True)
# Out:
#                Year      Games        Pts    Assist   Rebound
# Player
# Curry   2016.000000  69.666667  27.266667  6.466667  5.000000
# Durant  2016.000000  67.333333  26.566667  5.066667  7.766667
# Ibaka   2015.666667  52.333333  13.966667  0.866667  6.800000

# %% [markdown]
# ---

# %% [markdown]
# **NOTE:**
#
# The exercises below require you to run this notebook on Google Collab or locally on your machine.
#
# The jupyterlite environment cannot run the `wbgapi` package below due to a restriction in that package.
#
#
# <div align="center"><button><a href="https://colab.research.google.com/github/QuantEcon/africa-summer-course-2024/blob/main/exercises/day-09/exercise_set_9_with_solution.ipynb"><img src="" heght="10px"/><img
#   src="https://colab.research.google.com/assets/colab-badge.svg"
#   alt="open with Colab" width="200px"/></a></button></div>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 5
#
# Please read the following QuantEcon lecture before starting:
# - https://python-programming.quantecon.org/pandas.html
#
# From reading we know that we can use [wbg-api](https://pypi.org/project/wbgapi/) to access online data.

# %%
# %%capture
! pip install --upgrade wbgapi

# %%
import wbgapi as wb

# %% [markdown]
# ### Exercise 5.1
#
# Use [wb.series.info(q="")](https://pypi.org/project/wbgapi/) method to find the Gross Domestic Products per capita in constant 2015 US$.
#
# (Hint: use keywords, such as ``GDP`` or ``capita``.)

# %%
wb.series.info(q='gdp')
# Out:
# id                    value
# --------------------  -------------------------------------------------------------------------
# EG.GDP.PUSE.KO.PP     GDP per unit of energy use (PPP $ per kg of oil equivalent)
# EG.GDP.PUSE.KO.PP.KD  GDP per unit of energy use (constant 2021 PPP $ per kg of oil equivalent)
# EG.USE.COMM.GD.PP.KD  Energy use (kg of oil equivalent) per $1,000 GDP (constant 2021 PPP)
# NY.GDP.DEFL.KD.ZG     Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG.AD  Inflation, GDP deflator: linked series (annual %)
# NY.GDP.DEFL.ZS        GDP deflator (base year varies by country)
# NY.GDP.DEFL.ZS.AD     GDP deflator: linked series (base year varies by country)
# NY.GDP.DISC.CN        Discrepancy in expenditure estimate of GDP (current LCU)
# NY.GDP.DISC.KN        Discrepancy in expenditure estimate of GDP (constant LCU)
# NY.GDP.MKTP.CD        GDP (current US$)
# NY.GDP.MKTP.CN        GDP (current LCU)
# NY.GDP.MKTP.CN.AD     GDP: linked series (current LCU)
# NY.GDP.MKTP.KD        GDP (constant 2015 US$)
# NY.GDP.MKTP.KD.ZG     GDP growth (annual %)
# NY.GDP.MKTP.KN        GDP (constant LCU)
# NY.GDP.MKTP.PP.CD     GDP, PPP (current international $)
# NY.GDP.MKTP.PP.KD     GDP, PPP (constant 2021 international $)
# NY.GDP.PCAP.CD        GDP per capita (current US$)
# NY.GDP.PCAP.CN        GDP per capita (current LCU)
# NY.GDP.PCAP.KD        GDP per capita (constant 2015 US$)
# NY.GDP.PCAP.KD.ZG     GDP per capita growth (annual %)
# NY.GDP.PCAP.KN        GDP per capita (constant LCU)
# NY.GDP.PCAP.PP.CD     GDP per capita, PPP (current international $)
# NY.GDP.PCAP.PP.KD     GDP per capita, PPP (constant 2021 international $)
# PA.NUS.PPP            PPP conversion factor, GDP (LCU per international $)
# PA.NUS.PPPC.RF        Price level ratio of PPP conversion factor (GDP) to market exchange rate
# SL.GDP.PCAP.EM.KD     GDP per person employed (constant 2021 PPP $)
#                       27 elements

# %% [markdown]
# The series has ``id``: ``NY.GDP.PCAP.KD``.

# %% [markdown]
# ### Exercise 5.2
# Using the id you obtained from Exercise 2.1 to acquire GDP per capita data
# - for countries US (`USA`) and Australia (`AUS`)
# - from year 2000 to 2022,
#
# and store the data in a dataframe called ``dat``.

# %%
dat = wb.data.DataFrame(['NY.GDP.PCAP.KD'], ['USA', 'AUS'], range(2000, 2022+1))

# %%
dat
# Out:
#                YR2000        YR2001       YR2002        YR2003        YR2004  \
# economy
# AUS      45858.580093  46190.381208  47485.34109  48393.136722  49901.015296
# USA      48616.254626  48597.424614  48967.36612  49905.523307  51348.347338
#
#                YR2005        YR2006        YR2007        YR2008        YR2009  \
# economy
# AUS      50852.161202  51552.893830  52530.701893  53335.005704  53235.923582
# USA      52649.571305  53596.315237  54152.829265  53703.962896  51863.618341
#
#          ...        YR2011        YR2012        YR2013        YR2014  \
# economy  ...
# AUS      ...  54114.726191  55261.918378  55734.574341  56341.134149
# USA      ...  53259.255214  54080.228650  54844.242580  55817.563247
#
#                YR2015        YR2016        YR2017        YR2018        YR2019  \
# economy
# AUS      56758.869203  57432.180285  57804.050907  58600.790356  59000.735444
# USA      57040.208214  57658.670883  58703.144078  60127.210278  61330.645977
#
#                YR2020
# economy
# AUS      58082.426580
# USA      59394.778327
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Exercise 5.3
#
# Calculate the average GDP per capita for these two countries, respectively, over the period.
#
# (HINT: Use ``.mean()`` method and think about the shape of the data and which axis to calculate the mean over)

# %%
dat.mean(axis=1)
# Out:
# economy
# AUS    53430.843097
# USA    54213.265012
# dtype: float64

# %% [markdown]
# ### Exercise 5.4
#
# Plot the GDP per capita from 2000 to 2022 as time series for the two countries.

# %%
dat.T.plot(xlabel="years", ylabel="GDP per capita, Const$ 2015")
# Out:
# <Axes: xlabel='years', ylabel='GDP per capita, Const$ 2015'>

# %% [markdown]
# ## Exercise 6 (Climate change vs GDP growth)
#
# Next let's compare GDP per capita to the share of Droughts, floods and extreme temperatures around the world.

# %% [markdown]
# ### Exercise 6.1
#
# Use [wb.series.info()](https://pypi.org/project/wbgapi/) method to find the share of Droughts, floods, extreme temperatures.

# %%
wb.series.info(q='temperature')
# Out:
# id              value
# --------------  ---------------------------------------------------------------------------
# EN.CLC.MDAT.ZS  Droughts, floods, extreme temperatures (% of population, average 1990-2009)
#                 1 elements

# %% [markdown]
# ### Exercise 6.2
#
# Acquire the GDP per capita and the share of extreme weather for **ALL** available countries in year 2009 using ``id``s from Exercises 5.1 and 6.1.
#
# Store the acquired data in a dataframe called ``df`` and name the columns by ``gdp`` and ``eweather``, respectively.

# %% [markdown]
# Here a higher value in the column ``eweather`` means that the corresponding country experienced more extreme weather situations.

# %%
df = wb.data.DataFrame(['NY.GDP.PCAP.KD', 'EN.CLC.MDAT.ZS'], time=2009)

# %%
df
# Out:
#          EN.CLC.MDAT.ZS  NY.GDP.PCAP.KD
# economy
# ABW                 NaN    28836.017477
# AFE                 NaN     1418.634327
# AFG            1.059290      490.272834
# AFW                 NaN     1629.622659
# AGO            1.011765     3087.811430
# ...                 ...             ...
# XKX                 NaN     2676.707480
# YEM            0.099411     2435.766957
# ZAF            1.805651     5910.788246
# ZMB            4.199677     1125.089048
# ZWE                 NaN      914.494574
#
# [266 rows x 2 columns]

# %%
column_mapper = {
    'EN.CLC.MDAT.ZS' : 'eweather',
    'NY.GDP.PCAP.KD' : 'gdppc'
}

# %%
df = df.rename(columns=column_mapper)

# %%
df = df.dropna()

# %%
df
# Out:
#          eweather         gdppc
# economy
# AFG      1.059290    490.272834
# AGO      1.011765   3087.811430
# ALB      5.269577   3432.170872
# ARG      0.167190  12336.861939
# ARM      0.478231   2810.192841
# ...           ...           ...
# VUT      0.105704   2779.444011
# WSM      0.000000   3842.575971
# YEM      0.099411   2435.766957
# ZAF      1.805651   5910.788246
# ZMB      4.199677   1125.089048
#
# [165 rows x 2 columns]

# %% [markdown]
# ### Exercise 6.3
#
# Use the [statsmodels](https://www.statsmodels.org/stable/regression.html) package to assess the relation between ``gdp`` and ``eweather`` using ordinary least squares regression.

# %%
# %%capture
! pip install --upgrade statsmodels

# %%
import statsmodels.formula.api as sm

# %%
wog = sm.ols('eweather ~ np.log(gdppc)', df).fit()

# %%
print(wog.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               eweather   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     33.08
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           4.27e-08
# Time:                        10:23:56   Log-Likelihood:                -325.90
# No. Observations:                 165   AIC:                             655.8
# Df Residuals:                     163   BIC:                             662.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.8232      0.827      7.044      0.000       4.191       7.456
# np.log(gdppc)    -0.5614      0.098     -5.751      0.000      -0.754      -0.369
# ==============================================================================
# Omnibus:                       88.809   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              329.032
# Skew:                           2.177   Prob(JB):                     3.56e-72
# Kurtosis:                       8.376   Cond. No.                         51.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
